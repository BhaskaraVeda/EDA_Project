# %%
import pandas as pd

# %%
ame_exp = pd.read_csv(r"C:\Users\veda_\Desktop\Data Analysis Innomatics\Project Presentation\exports-to-american-countries.csv")

# %%
eur_exp = pd.read_csv(r"C:\Users\veda_\Desktop\Data Analysis Innomatics\Project Presentation\exports-to-european-countries.csv")

# %%
# Concatenate two datasets
exports_data = pd.concat([ame_exp, eur_exp], axis=0)

# %%
exports_data.reset_index()
# Out:
#            index       id        date                country_name  \
# 0              0        0  2022-01-01    United States of America
# 1              1        1  2022-01-01    United States of America
# 2              2        2  2022-01-01    United States of America
# 3              3        3  2022-01-01    United States of America
# 4              4        4  2022-01-01    United States of America
# ...          ...      ...         ...                         ...
# 4962643  3072301  3072301  2021-12-01                      Sweden
# 4962644  3072302  3072302  2021-12-01  Kingdom of the Netherlands
# 4962645  3072303  3072303  2021-12-01                    Portugal
# 4962646  3072304  3072304  2021-12-01                     Germany
# 4962647  3072305  3072305  2021-12-01                      Poland
#
#         alpha_3_code  country_code    region  region_code        sub_region  \
# 0                USA         840.0  Americas           19  Northern America
# ...

# %%
exports_data.head(3)
# Out:
#    id        date              country_name alpha_3_code  country_code  \
# 0   0  2022-01-01  United States of America          USA         840.0
# 1   1  2022-01-01  United States of America          USA         840.0
# 2   2  2022-01-01  United States of America          USA         840.0
#
#      region  region_code        sub_region  sub_region_code  hs_code  \
# 0  Americas           19  Northern America               21  2062900
# 1  Americas           19  Northern America               21  3011100
# 2  Americas           19  Northern America               21  3023200
#
#                                     commodity unit  value_qt  value_rs  \
# 0  Othr Edible Offal Of Bovine Animals,Frozen  Kgs     50.00     39.21
# 1                  Freshwater Ornamental Fish  Kgs      0.45      2.36
# 2            Yellowfin Tunas Fresh Or Chilled  Kgs      2.20      9.62
#
#    value_dl
# 0      0.05
# 1      0.00
# 2      0.01

# %%
exports_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4962648 entries, 0 to 3072305
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   id               int64
#  1   date             object
#  2   country_name     object
#  3   alpha_3_code     object
#  4   country_code     float64
#  5   region           object
#  6   region_code      int64
#  7   sub_region       object
#  8   sub_region_code  int64
#  9   hs_code          int64
#  10  commodity        object
#  11  unit             object
#  12  value_qt         float64
#  13  value_rs         float64
#  14  value_dl         float64
# dtypes: float64(4), int64(4), object(7)
# memory usage: 605.8+ MB

# %%
exports_data.to_csv('exports_to_western_countries.csv', index=False)

# %%
pd.read_csv(r"C:\Users\veda_\Desktop\Data Analysis Innomatics\Project Presentation\exports_to_western_countries.csv")
# Out:
#               id        date                country_name alpha_3_code  \
# 0              0  2022-01-01    United States of America          USA
# 1              1  2022-01-01    United States of America          USA
# 2              2  2022-01-01    United States of America          USA
# 3              3  2022-01-01    United States of America          USA
# 4              4  2022-01-01    United States of America          USA
# ...          ...         ...                         ...          ...
# 4962643  3072301  2021-12-01                      Sweden          SWE
# 4962644  3072302  2021-12-01  Kingdom of the Netherlands          NLD
# 4962645  3072303  2021-12-01                    Portugal          PRT
# 4962646  3072304  2021-12-01                     Germany          DEU
# 4962647  3072305  2021-12-01                      Poland          POL
#
#          country_code    region  region_code        sub_region  \
# ...
